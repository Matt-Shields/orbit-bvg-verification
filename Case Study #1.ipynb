# %% [markdown]
# ### Cost model benchmarking - case study #1
#
# Loosely based on Dudgeon Wind Farm (400 MW, 8MW turbines)
#
# National Renewable Energy Lab
#
# Matt Shields, Jake Nunemaker
#
# Updated: 2/17/2020

# %%
import os
import sys
import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as plt_dates

import ORBIT
print(f"Using ORBIT version {ORBIT.__version__}.")
from ORBIT import ProjectManager


usd_to_euro = 0.92
# Out:
# Using ORBIT version 0+unknown.

# %% [markdown]
# #### Weather File

# %%
filepath = os.path.join('library', 'weather', 'dudgeon_wave_100m_wind.csv')
weather = pd.read_csv(filepath, parse_dates=["datetime"]).set_index(keys='datetime')
weather.describe()
# Out:
#           windspeed    waveheight
# count  20616.000000  20616.000000
# mean       9.138532      1.183350
# std        4.249767      0.667603
# min        0.121744      0.170372
# 25%        5.980583      0.698537
# 50%        8.916669      1.027665
# 75%       11.878717      1.507961
# max       25.680700      5.773216

# %% [markdown]
# #### ORBIT Configuration

# %%
phases = [
    # Substructures
    'MonopileInstallation',
#     'ScourProtectionDesign',
#     'ScourProtectionInstallation',
    
    # Turbines
    'TurbineInstallation',
    
#     # Electrical
    'ArraySystemDesign',
    'ArrayCableInstallation',
    'ExportSystemDesign',
    'ExportCableInstallation',
    'OffshoreSubstationDesign',
    'OffshoreSubstationInstallation'
]

required_config = ProjectManager.compile_input_dict(phases)
# required_config

# %%
config = {
    # Substations
#     "num_substations": 1,
    
    # Vessels
#     'scour_protection_install_vessel': 'ExampleScour',
#     'trench_dig_vessel': 'StematSpirit',
#     'array_cable_lay_vessel': 'cable_lay_vessel',
#     'export_cable_lay_vessel': 'StematSpirit',
#     "oss_install_vessel": "OlegStrashnov",  # Actually vessel from SPT Offshore
    
    # Site/plant
    'site': {
        'depth': 22.5,
        'distance': 124,
        'distance_to_landfall': 42,
        'distance_to_beach': 0,
        'distance_to_interconnection': 3,
        'mean_windspeed': 9.13
    },
    
    'plant': {
        'layout': 'grid',
        'num_turbines': 50,
        'row_spacing': 7,
        'turbine_spacing': 9,
        'substation_distance': 1
    },
    
    'port': {
        'num_cranes': 1,
        'monthly_rate': 2000000,
        "name": "Green Port"
    },
    
    # Turbine + components
    'turbine': '8MW_generic',

    # Substructure components
    'substructure': {'diameter': 7.2},
    'monopile': {
        'type': 'Monopile',
        'length': 69,
        'diameter': 7.2,
        'deck_space': 496.8,
        'mass': 800,
        'monopile_steel_cost' : 2000 / usd_to_euro,
    },
    
    'transition_piece': {
        'type': 'Transition Piece',
        'deck_space': 100,
        'mass': 400,
        'transition_piece_steel_cost' : 2000 / usd_to_euro,
    },
    
    'scour_protection_design': {
        'cost_per_tonne': 40,
#         'scour_protection_depth':0.3
    },
    
    # Electrical
    'array_system_design': {
        'cables': 'XLPE_630mm_66kV'
    },
    
    'array_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system_design': {
        'cables': 'XLPE_1000mm_220kV',
        'percent_added_length': 0
    },
    
    'substation_design': {
        'num_substations': 2
    },
    
#     "offshore_substation_topside": {
#         "type": "Topside",
#         "deck_space": 200,
#         "weight": 2000,
#     },
#     "offshore_substation_substructure": {
#         "type": "Monopile",
#         "deck_space": 500,
#         "weight": 1850,
#         "length": 69,  # Assumed to be the same as monopile length
#     },


    # Phase specific configurations
    'MonopileInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine',  
        
    },
    
    'TurbineInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine'
    },
    
    'ArrayCableInstallation': {
        'array_cable_install_vessel' : 'cable_lay_vessel'
    }, 
    
    'ExportCableInstallation': {
        'export_cable_install_vessel' : 'cable_lay_vessel'
    },
    
    'OffshoreSubstationInstallation': {
        "num_feeders": 1,
        "feeder": "future_large_feeder",
        "oss_install_vessel": "heavy_lift_vessel"
    },    
    
    'ScourProtectionInstallation': {
        'spi_vessel': 'example_scour_protection_vessel'
    },
    
    # Phases
    'design_phases': [
#         "MonopileDesign",
        'ScourProtectionDesign',
        'ArraySystemDesign',
        'ExportSystemDesign',
        'OffshoreSubstationDesign'
    ],
    
    'install_phases': {
        'MonopileInstallation': '07/01/2016',         # Updated dates 
        'ScourProtectionInstallation': '07/01/2016',  # Placed at the end of the monopile installation
        'TurbineInstallation': '07/01/2016',
        'ArrayCableInstallation': '07/01/2016',
        'ExportCableInstallation': '07/01/2016',
        'OffshoreSubstationInstallation': '07/01/2016'
    }
}

# %%
path = os.path.join(os.getcwd(), "library")
project = ProjectManager(config, weather=weather, library_path=path)
# Out:
# ORBIT library intialized at 'C:\Users\mshields\Documents\Projects\ORBIT development\Code benchmarking\orbit-benchmarking\library'

# %%
project.run_project()

# %% [markdown]
# # Results
#
# ### Turbine installation

# %%
# Trip data
project._phases['TurbineInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=1506, deck_space=1942, items={TowerSection: 4, Nacelle: 2, Blade: 6})]

# %%
# Installation costs 
turb_time = np.round(project._phases['TurbineInstallation'].total_phase_time * (1/24) ,1 ) # Convert hours to days
turb_cost = np.round(project._phases['TurbineInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)

print('Turbine install time: ', turb_time, 'days')
print('Turbine install cost: ', turb_cost, 'M Euros')
# Out:
# Turbine install time:  149.1 days
# Turbine install cost:  39.8 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='TurbineInstallation']
# Out:
#                      action agent  cable_lay_speed          cost  \
# 2                  Mobilize  WTIV              NaN  1.085000e+06
# 9      Fasten Tower Section  WTIV              NaN  3.616667e+04
# 15     Fasten Tower Section  WTIV              NaN  3.616667e+04
# 17           Fasten Nacelle  WTIV              NaN  3.616667e+04
# 21             Fasten Blade  WTIV              NaN  1.356250e+04
# 24             Fasten Blade  WTIV              NaN  1.356250e+04
# 26             Fasten Blade  WTIV              NaN  1.356250e+04
# 31     Fasten Tower Section  WTIV              NaN  3.616667e+04
# 33     Fasten Tower Section  WTIV              NaN  3.616667e+04
# 39           Fasten Nacelle  WTIV              NaN  3.616667e+04
# 40             Fasten Blade  WTIV              NaN  1.356250e+04
# 41             Fasten Blade  WTIV              NaN  1.356250e+04
# 43             Fasten Blade  WTIV              NaN  1.356250e+04
# 46     Fasten Tower Section  WTIV              NaN  3.616667e+04
# 50     Fasten Tower Section  WTIV              NaN  3.616667e+04
# 53           Fasten Nacelle  WTIV              NaN  3.616667e+04
# 56             Fasten Blade  WTIV              NaN  1.356250e+04
# 58             Fasten Blade  WTIV              NaN  1.356250e+04
# 62             Fasten Blade  WTIV              NaN  1.356250e+04
# 67     Fasten Tower Section  WTIV              NaN  3.616667e+04
# 73     Fasten Tower Section  WTIV              NaN  3.616667e+04
# 79           Fasten Nacelle  WTIV              NaN  3.616667e+04
# 80             Fasten Blade  WTIV              NaN  1.356250e+04
# 83             Fasten Blade  WTIV              NaN  1.356250e+04
# 86             Fasten Blade  WTIV              NaN  1.356250e+04
# 95                  Transit  WTIV              NaN  7.474444e+04
# 100         Position Onsite  WTIV              NaN  1.808333e+04
# 102                  Jackup  WTIV              NaN  1.224392e+04
# 106   Release Tower Section  WTIV              NaN  2.712500e+04
# 107      Lift Tower Section  WTIV              NaN  1.192998e+02
# ...                     ...   ...              ...           ...
# 2921          Release Blade  WTIV              NaN  9.041667e+03
# 2922             Lift Blade  WTIV              NaN  2.365066e+02
# 2923           Attach Blade  WTIV              NaN  3.164583e+04
# 2924          Release Blade  WTIV              NaN  9.041667e+03
# 2925             Lift Blade  WTIV              NaN  2.365066e+02
# 2926           Attach Blade  WTIV              NaN  3.164583e+04
# 2927               Jackdown  WTIV              NaN  1.224392e+04
# 2928        Position Onsite  WTIV              NaN  1.808333e+04
# 2929                 Jackup  WTIV              NaN  1.224392e+04
# 2930  Release Tower Section  WTIV              NaN  2.712500e+04
# 2931     Lift Tower Section  WTIV              NaN  1.192998e+02
# 2932   Attach Tower Section  WTIV              NaN  5.425000e+04
# 2933  Release Tower Section  WTIV              NaN  2.712500e+04
# 2934     Lift Tower Section  WTIV              NaN  2.385995e+02
# 2935   Attach Tower Section  WTIV              NaN  5.425000e+04
# 2936        Release Nacelle  WTIV              NaN  2.712500e+04
# 2937                Reequip  WTIV              NaN  9.041667e+03
# 2938           Lift Nacelle  WTIV              NaN  2.365066e+02
# 2939         Attach Nacelle  WTIV              NaN  5.425000e+04
# 2940                Reequip  WTIV              NaN  9.041667e+03
# 2941          Release Blade  WTIV              NaN  9.041667e+03
# 2942             Lift Blade  WTIV              NaN  2.365066e+02
# 2943           Attach Blade  WTIV              NaN  3.164583e+04
# 2944          Release Blade  WTIV              NaN  9.041667e+03
# 2945             Lift Blade  WTIV              NaN  2.365066e+02
# 2946           Attach Blade  WTIV              NaN  3.164583e+04
# 2947          Release Blade  WTIV              NaN  9.041667e+03
# 2948             Lift Blade  WTIV              NaN  2.365066e+02
# 2949           Attach Blade  WTIV              NaN  3.164583e+04
# 2950               Jackdown  WTIV              NaN  1.224392e+04
#
#       cost_multiplier    duration  hub_height   level location  \
# 2                 1.0  120.000000         NaN  ACTION      NaN
# 9                 NaN    4.000000       113.0  ACTION      NaN
# 15                NaN    4.000000       113.0  ACTION      NaN
# 17                NaN    4.000000       113.0  ACTION      NaN
# 21                NaN    1.500000       113.0  ACTION      NaN
# 24                NaN    1.500000       113.0  ACTION      NaN
# 26                NaN    1.500000       113.0  ACTION      NaN
# 31                NaN    4.000000       113.0  ACTION      NaN
# 33                NaN    4.000000       113.0  ACTION      NaN
# 39                NaN    4.000000       113.0  ACTION      NaN
# 40                NaN    1.500000       113.0  ACTION      NaN
# 41                NaN    1.500000       113.0  ACTION      NaN
# 43                NaN    1.500000       113.0  ACTION      NaN
# 46                NaN    4.000000       113.0  ACTION      NaN
# 50                NaN    4.000000       113.0  ACTION      NaN
# 53                NaN    4.000000       113.0  ACTION      NaN
# 56                NaN    1.500000       113.0  ACTION      NaN
# 58                NaN    1.500000       113.0  ACTION      NaN
# 62                NaN    1.500000       113.0  ACTION      NaN
# 67                NaN    4.000000       113.0  ACTION      NaN
# 73                NaN    4.000000       113.0  ACTION      NaN
# 79                NaN    4.000000       113.0  ACTION      NaN
# 80                NaN    1.500000       113.0  ACTION      NaN
# 83                NaN    1.500000       113.0  ACTION      NaN
# 86                NaN    1.500000       113.0  ACTION      NaN
# 95                NaN    8.266667         NaN  ACTION      NaN
# 100               NaN    2.000000         NaN  ACTION      NaN
# 102               NaN    1.354167       113.0  ACTION      NaN
# 106               NaN    3.000000         NaN  ACTION      NaN
# 107               NaN    0.013194       113.0  ACTION      NaN
# ...               ...         ...         ...     ...      ...
# 2921              NaN    1.000000         NaN  ACTION      NaN
# 2922              NaN    0.026157       113.0  ACTION      NaN
# 2923              NaN    3.500000       113.0  ACTION      NaN
# 2924              NaN    1.000000         NaN  ACTION      NaN
# 2925              NaN    0.026157       113.0  ACTION      NaN
# 2926              NaN    3.500000       113.0  ACTION      NaN
# 2927              NaN    1.354167         NaN  ACTION      NaN
# 2928              NaN    2.000000         NaN  ACTION      NaN
# 2929              NaN    1.354167       113.0  ACTION      NaN
# 2930              NaN    3.000000         NaN  ACTION      NaN
# 2931              NaN    0.013194       113.0  ACTION      NaN
# 2932              NaN    6.000000       113.0  ACTION      NaN
# 2933              NaN    3.000000         NaN  ACTION      NaN
# 2934              NaN    0.026389       113.0  ACTION      NaN
# 2935              NaN    6.000000       113.0  ACTION      NaN
# 2936              NaN    3.000000         NaN  ACTION      NaN
# 2937              NaN    1.000000         NaN  ACTION      NaN
# 2938              NaN    0.026157       113.0  ACTION      NaN
# 2939              NaN    6.000000       113.0  ACTION      NaN
# 2940              NaN    1.000000         NaN  ACTION      NaN
# 2941              NaN    1.000000         NaN  ACTION      NaN
# 2942              NaN    0.026157       113.0  ACTION      NaN
# 2943              NaN    3.500000       113.0  ACTION      NaN
# 2944              NaN    1.000000         NaN  ACTION      NaN
# 2945              NaN    0.026157       113.0  ACTION      NaN
# 2946              NaN    3.500000       113.0  ACTION      NaN
# 2947              NaN    1.000000         NaN  ACTION      NaN
# 2948              NaN    0.026157       113.0  ACTION      NaN
# 2949              NaN    3.500000       113.0  ACTION      NaN
# 2950              NaN    1.354167         NaN  ACTION      NaN
#
#       max_waveheight  max_windspeed                phase           phase_name  \
# 2                NaN            NaN  TurbineInstallation                  NaN
# 9                NaN            NaN  TurbineInstallation  TurbineInstallation
# 15               NaN            NaN  TurbineInstallation  TurbineInstallation
# 17               NaN            NaN  TurbineInstallation  TurbineInstallation
# 21               NaN            NaN  TurbineInstallation  TurbineInstallation
# 24               NaN            NaN  TurbineInstallation  TurbineInstallation
# 26               NaN            NaN  TurbineInstallation  TurbineInstallation
# 31               NaN            NaN  TurbineInstallation  TurbineInstallation
# 33               NaN            NaN  TurbineInstallation  TurbineInstallation
# 39               NaN            NaN  TurbineInstallation  TurbineInstallation
# 40               NaN            NaN  TurbineInstallation  TurbineInstallation
# 41               NaN            NaN  TurbineInstallation  TurbineInstallation
# 43               NaN            NaN  TurbineInstallation  TurbineInstallation
# 46               NaN            NaN  TurbineInstallation  TurbineInstallation
# 50               NaN            NaN  TurbineInstallation  TurbineInstallation
# 53               NaN            NaN  TurbineInstallation  TurbineInstallation
# 56               NaN            NaN  TurbineInstallation  TurbineInstallation
# 58               NaN            NaN  TurbineInstallation  TurbineInstallation
# 62               NaN            NaN  TurbineInstallation  TurbineInstallation
# 67               NaN            NaN  TurbineInstallation  TurbineInstallation
# 73               NaN            NaN  TurbineInstallation  TurbineInstallation
# 79               NaN            NaN  TurbineInstallation  TurbineInstallation
# 80               NaN            NaN  TurbineInstallation  TurbineInstallation
# 83               NaN            NaN  TurbineInstallation  TurbineInstallation
# 86               NaN            NaN  TurbineInstallation  TurbineInstallation
# 95               NaN            NaN  TurbineInstallation                  NaN
# 100              NaN            NaN  TurbineInstallation                  NaN
# 102              NaN            NaN  TurbineInstallation  TurbineInstallation
# 106              NaN            NaN  TurbineInstallation                  NaN
# 107              NaN            NaN  TurbineInstallation  TurbineInstallation
# ...              ...            ...                  ...                  ...
# 2921             NaN            NaN  TurbineInstallation                  NaN
# 2922             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2923             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2924             NaN            NaN  TurbineInstallation                  NaN
# 2925             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2926             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2927             NaN            NaN  TurbineInstallation                  NaN
# 2928             NaN            NaN  TurbineInstallation                  NaN
# 2929             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2930             NaN            NaN  TurbineInstallation                  NaN
# 2931             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2932             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2933             NaN            NaN  TurbineInstallation                  NaN
# 2934             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2935             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2936             NaN            NaN  TurbineInstallation                  NaN
# 2937             NaN            NaN  TurbineInstallation                  NaN
# 2938             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2939             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2940             NaN            NaN  TurbineInstallation                  NaN
# 2941             NaN            NaN  TurbineInstallation                  NaN
# 2942             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2943             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2944             NaN            NaN  TurbineInstallation                  NaN
# 2945             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2946             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2947             NaN            NaN  TurbineInstallation                  NaN
# 2948             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2949             NaN            NaN  TurbineInstallation  TurbineInstallation
# 2950             NaN            NaN  TurbineInstallation                  NaN
#
#       site_depth         time  transit_speed
# 2            NaN     0.000000            NaN
# 9           22.5     4.000000            NaN
# 15          22.5     8.000000            NaN
# 17          22.5    12.000000            NaN
# 21          22.5    13.500000            NaN
# 24          22.5    15.000000            NaN
# 26          22.5    16.500000            NaN
# 31          22.5    20.500000            NaN
# 33          22.5    24.500000            NaN
# 39          22.5    28.500000            NaN
# 40          22.5    30.000000            NaN
# 41          22.5    31.500000            NaN
# 43          22.5    33.000000            NaN
# 46          22.5    37.000000            NaN
# 50          22.5    41.000000            NaN
# 53          22.5    45.000000            NaN
# 56          22.5    46.500000            NaN
# 58          22.5    48.000000            NaN
# 62          22.5    49.500000            NaN
# 67          22.5    53.500000            NaN
# 73          22.5    57.500000            NaN
# 79          22.5    61.500000            NaN
# 80          22.5    63.000000            NaN
# 83          22.5    64.500000            NaN
# 86          22.5    66.000000            NaN
# 95           NaN    74.266667            NaN
# 100          NaN    76.266667            NaN
# 102         22.5    77.620833            NaN
# 106          NaN    80.620833            NaN
# 107         22.5    80.634028            NaN
# ...          ...          ...            ...
# 2921         NaN  3520.534954            NaN
# 2922        22.5  3520.561111            NaN
# 2923        22.5  3524.061111            NaN
# 2924         NaN  3525.061111            NaN
# 2925        22.5  3525.087269            NaN
# 2926        22.5  3528.587269            NaN
# 2927         NaN  3529.941435            NaN
# 2928         NaN  3531.941435            NaN
# 2929        22.5  3533.295602            NaN
# 2930         NaN  3536.295602            NaN
# 2931        22.5  3536.308796            NaN
# 2932        22.5  3542.308796            NaN
# 2933         NaN  3545.308796            NaN
# 2934        22.5  3545.335185            NaN
# 2935        22.5  3551.335185            NaN
# 2936         NaN  3554.335185            NaN
# 2937         NaN  3555.335185            NaN
# 2938        22.5  3555.361343            NaN
# 2939        22.5  3561.361343            NaN
# 2940         NaN  3562.361343            NaN
# 2941         NaN  3563.361343            NaN
# 2942        22.5  3563.387500            NaN
# 2943        22.5  3566.887500            NaN
# 2944         NaN  3567.887500            NaN
# 2945        22.5  3567.913657            NaN
# 2946        22.5  3571.413657            NaN
# 2947         NaN  3572.413657            NaN
# 2948        22.5  3572.439815            NaN
# 2949        22.5  3575.939815            NaN
# 2950         NaN  3577.293981            NaN
#
# [1493 rows x 16 columns]

# %% [markdown]
# ### Monopile design and installation

# %%
# Trip data
project._phases['MonopileInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=2400, deck_space=1193.6, items={Monopile: 2, TransitionPiece: 2})]

# %%
# Installation and capital costs 
mono_time = np.round(project._phases['MonopileInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
mono_install_cost = np.round(project._phases['MonopileInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
mono_capital_cost = np.round(((config['monopile']['mass'] * 
                     config['plant']['num_turbines'] * 
                     config['monopile']['monopile_steel_cost']) +
                     (config['transition_piece']['mass'] * 
                     config['plant']['num_turbines'] * 
                     config['transition_piece']['transition_piece_steel_cost']))* 1e-6 * usd_to_euro , 1)

print('Monopile install time: ', mono_time, 'days')
print('Monopile install cost: ', mono_install_cost, 'M Euros')
print('Monopile capital cost: ', mono_capital_cost, 'M Euros')
print('Monopile total cost: ', mono_capital_cost + mono_install_cost, 'M Euros')
# Out:
# Monopile install time:  87.4 days
# Monopile install cost:  23.7 M Euros
# Monopile capital cost:  120.0 M Euros
# Monopile total cost:  143.7 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='MonopileInstallation']
# Out:
#                         action agent  cable_lay_speed          cost  \
# 0                     Mobilize  WTIV              NaN  1.085000e+06
# 16             Fasten Monopile  WTIV              NaN  1.085000e+05
# 30     Fasten Transition Piece  WTIV              NaN  7.233333e+04
# 42             Fasten Monopile  WTIV              NaN  1.085000e+05
# 49     Fasten Transition Piece  WTIV              NaN  7.233333e+04
# 64             Fasten Monopile  WTIV              NaN  1.085000e+05
# 78     Fasten Transition Piece  WTIV              NaN  7.233333e+04
# 91             Fasten Monopile  WTIV              NaN  1.085000e+05
# 104    Fasten Transition Piece  WTIV              NaN  7.233333e+04
# 120            Fasten Monopile  WTIV              NaN  1.085000e+05
# 128    Fasten Transition Piece  WTIV              NaN  7.233333e+04
# 141            Fasten Monopile  WTIV              NaN  1.085000e+05
# 151    Fasten Transition Piece  WTIV              NaN  7.233333e+04
# 161                    Transit  WTIV              NaN  7.474444e+04
# 162            Position Onsite  WTIV              NaN  1.808333e+04
# 164                     Jackup  WTIV              NaN  1.224392e+04
# 166                  RovSurvey  WTIV              NaN  9.041667e+03
# 171           Release Monopile  WTIV              NaN  2.712500e+04
# 172             Upend Monopile  WTIV              NaN  1.444155e+02
# 173             Lower Monopile  WTIV              NaN  1.816822e-02
# 174              Crane Reequip  WTIV              NaN  9.041667e+03
# 177             Drive Monopile  WTIV              NaN  1.356250e+04
# 180   Release Transition Piece  WTIV              NaN  1.808333e+04
# 181              Crane Reequip  WTIV              NaN  9.041667e+03
# 182                   Lower TP  WTIV              NaN  2.092978e+01
# 184                    Bolt TP  WTIV              NaN  3.616667e+04
# 187                   Jackdown  WTIV              NaN  1.224392e+04
# 190            Position Onsite  WTIV              NaN  1.808333e+04
# 191                     Jackup  WTIV              NaN  1.224392e+04
# 193                  RovSurvey  WTIV              NaN  9.041667e+03
# ...                        ...   ...              ...           ...
# 2289   Fasten Transition Piece  WTIV              NaN  7.233333e+04
# 2293                   Transit  WTIV              NaN  7.474444e+04
# 2294           Position Onsite  WTIV              NaN  1.808333e+04
# 2297                    Jackup  WTIV              NaN  1.224392e+04
# 2298                 RovSurvey  WTIV              NaN  9.041667e+03
# 2299          Release Monopile  WTIV              NaN  2.712500e+04
# 2300                     Delay  WTIV              NaN  9.041667e+04
# 2301            Upend Monopile  WTIV              NaN  1.444155e+02
# 2302            Lower Monopile  WTIV              NaN  1.816822e-02
# 2303             Crane Reequip  WTIV              NaN  9.041667e+03
# 2305                     Delay  WTIV              NaN  1.808333e+04
# 2306            Drive Monopile  WTIV              NaN  1.356250e+04
# 2307  Release Transition Piece  WTIV              NaN  1.808333e+04
# 2308             Crane Reequip  WTIV              NaN  9.041667e+03
# 2309                  Lower TP  WTIV              NaN  2.092978e+01
# 2312                   Bolt TP  WTIV              NaN  3.616667e+04
# 2315                  Jackdown  WTIV              NaN  1.224392e+04
# 2316           Position Onsite  WTIV              NaN  1.808333e+04
# 2317                    Jackup  WTIV              NaN  1.224392e+04
# 2318                 RovSurvey  WTIV              NaN  9.041667e+03
# 2321          Release Monopile  WTIV              NaN  2.712500e+04
# 2322            Upend Monopile  WTIV              NaN  1.444155e+02
# 2323            Lower Monopile  WTIV              NaN  1.816822e-02
# 2326             Crane Reequip  WTIV              NaN  9.041667e+03
# 2327            Drive Monopile  WTIV              NaN  1.356250e+04
# 2329  Release Transition Piece  WTIV              NaN  1.808333e+04
# 2332             Crane Reequip  WTIV              NaN  9.041667e+03
# 2333                  Lower TP  WTIV              NaN  2.092978e+01
# 2337                   Bolt TP  WTIV              NaN  3.616667e+04
# 2338                  Jackdown  WTIV              NaN  1.224392e+04
#
#       cost_multiplier    duration  hub_height   level location  \
# 0                 1.0  120.000000         NaN  ACTION      NaN
# 16                NaN   12.000000       113.0  ACTION      NaN
# 30                NaN    8.000000       113.0  ACTION      NaN
# 42                NaN   12.000000       113.0  ACTION      NaN
# 49                NaN    8.000000       113.0  ACTION      NaN
# 64                NaN   12.000000       113.0  ACTION      NaN
# 78                NaN    8.000000       113.0  ACTION      NaN
# 91                NaN   12.000000       113.0  ACTION      NaN
# 104               NaN    8.000000       113.0  ACTION      NaN
# 120               NaN   12.000000       113.0  ACTION      NaN
# 128               NaN    8.000000       113.0  ACTION      NaN
# 141               NaN   12.000000       113.0  ACTION      NaN
# 151               NaN    8.000000       113.0  ACTION      NaN
# 161               NaN    8.266667         NaN  ACTION      NaN
# 162               NaN    2.000000         NaN  ACTION      NaN
# 164               NaN    1.354167       113.0  ACTION      NaN
# 166               NaN    1.000000       113.0  ACTION      NaN
# 171               NaN    3.000000         NaN  ACTION      NaN
# 172               NaN    0.015972       113.0  ACTION      NaN
# 173               NaN    0.000002       113.0  ACTION      NaN
# 174               NaN    1.000000       113.0  ACTION      NaN
# 177               NaN    1.500000       113.0  ACTION      NaN
# 180               NaN    2.000000         NaN  ACTION      NaN
# 181               NaN    1.000000       113.0  ACTION      NaN
# 182               NaN    0.002315       113.0  ACTION      NaN
# 184               NaN    4.000000       113.0  ACTION      NaN
# 187               NaN    1.354167       113.0  ACTION      NaN
# 190               NaN    2.000000         NaN  ACTION      NaN
# 191               NaN    1.354167       113.0  ACTION      NaN
# 193               NaN    1.000000       113.0  ACTION      NaN
# ...               ...         ...         ...     ...      ...
# 2289              NaN    8.000000       113.0  ACTION      NaN
# 2293              NaN    8.266667         NaN  ACTION      NaN
# 2294              NaN    2.000000         NaN  ACTION      NaN
# 2297              NaN    1.354167       113.0  ACTION      NaN
# 2298              NaN    1.000000       113.0  ACTION      NaN
# 2299              NaN    3.000000         NaN  ACTION      NaN
# 2300              NaN   10.000000       113.0  ACTION      NaN
# 2301              NaN    0.015972       113.0  ACTION      NaN
# 2302              NaN    0.000002       113.0  ACTION      NaN
# 2303              NaN    1.000000       113.0  ACTION      NaN
# 2305              NaN    2.000000       113.0  ACTION      NaN
# 2306              NaN    1.500000       113.0  ACTION      NaN
# 2307              NaN    2.000000         NaN  ACTION      NaN
# 2308              NaN    1.000000       113.0  ACTION      NaN
# 2309              NaN    0.002315       113.0  ACTION      NaN
# 2312              NaN    4.000000       113.0  ACTION      NaN
# 2315              NaN    1.354167       113.0  ACTION      NaN
# 2316              NaN    2.000000         NaN  ACTION      NaN
# 2317              NaN    1.354167       113.0  ACTION      NaN
# 2318              NaN    1.000000       113.0  ACTION      NaN
# 2321              NaN    3.000000         NaN  ACTION      NaN
# 2322              NaN    0.015972       113.0  ACTION      NaN
# 2323              NaN    0.000002       113.0  ACTION      NaN
# 2326              NaN    1.000000       113.0  ACTION      NaN
# 2327              NaN    1.500000       113.0  ACTION      NaN
# 2329              NaN    2.000000         NaN  ACTION      NaN
# 2332              NaN    1.000000       113.0  ACTION      NaN
# 2333              NaN    0.002315       113.0  ACTION      NaN
# 2337              NaN    4.000000       113.0  ACTION      NaN
# 2338              NaN    1.354167       113.0  ACTION      NaN
#
#       max_waveheight  max_windspeed                 phase  \
# 0                NaN            NaN  MonopileInstallation
# 16               NaN            NaN  MonopileInstallation
# 30               NaN            NaN  MonopileInstallation
# 42               NaN            NaN  MonopileInstallation
# 49               NaN            NaN  MonopileInstallation
# 64               NaN            NaN  MonopileInstallation
# 78               NaN            NaN  MonopileInstallation
# 91               NaN            NaN  MonopileInstallation
# 104              NaN            NaN  MonopileInstallation
# 120              NaN            NaN  MonopileInstallation
# 128              NaN            NaN  MonopileInstallation
# 141              NaN            NaN  MonopileInstallation
# 151              NaN            NaN  MonopileInstallation
# 161              NaN            NaN  MonopileInstallation
# 162              NaN            NaN  MonopileInstallation
# 164              NaN            NaN  MonopileInstallation
# 166              NaN            NaN  MonopileInstallation
# 171              NaN            NaN  MonopileInstallation
# 172              NaN            NaN  MonopileInstallation
# 173              NaN            NaN  MonopileInstallation
# 174              NaN            NaN  MonopileInstallation
# 177              NaN            NaN  MonopileInstallation
# 180              NaN            NaN  MonopileInstallation
# 181              NaN            NaN  MonopileInstallation
# 182              NaN            NaN  MonopileInstallation
# 184              NaN            NaN  MonopileInstallation
# 187              NaN            NaN  MonopileInstallation
# 190              NaN            NaN  MonopileInstallation
# 191              NaN            NaN  MonopileInstallation
# 193              NaN            NaN  MonopileInstallation
# ...              ...            ...                   ...
# 2289             NaN            NaN  MonopileInstallation
# 2293             NaN            NaN  MonopileInstallation
# 2294             NaN            NaN  MonopileInstallation
# 2297             NaN            NaN  MonopileInstallation
# 2298             NaN            NaN  MonopileInstallation
# 2299             NaN            NaN  MonopileInstallation
# 2300             NaN            NaN  MonopileInstallation
# 2301             NaN            NaN  MonopileInstallation
# 2302             NaN            NaN  MonopileInstallation
# 2303             NaN            NaN  MonopileInstallation
# 2305             NaN            NaN  MonopileInstallation
# 2306             NaN            NaN  MonopileInstallation
# 2307             NaN            NaN  MonopileInstallation
# 2308             NaN            NaN  MonopileInstallation
# 2309             NaN            NaN  MonopileInstallation
# 2312             NaN            NaN  MonopileInstallation
# 2315             NaN            NaN  MonopileInstallation
# 2316             NaN            NaN  MonopileInstallation
# 2317             NaN            NaN  MonopileInstallation
# 2318             NaN            NaN  MonopileInstallation
# 2321             NaN            NaN  MonopileInstallation
# 2322             NaN            NaN  MonopileInstallation
# 2323             NaN            NaN  MonopileInstallation
# 2326             NaN            NaN  MonopileInstallation
# 2327             NaN            NaN  MonopileInstallation
# 2329             NaN            NaN  MonopileInstallation
# 2332             NaN            NaN  MonopileInstallation
# 2333             NaN            NaN  MonopileInstallation
# 2337             NaN            NaN  MonopileInstallation
# 2338             NaN            NaN  MonopileInstallation
#
#                 phase_name  site_depth         time  transit_speed
# 0                      NaN         NaN     0.000000            NaN
# 16    MonopileInstallation        22.5    12.000000            NaN
# 30    MonopileInstallation        22.5    20.000000            NaN
# 42    MonopileInstallation        22.5    32.000000            NaN
# 49    MonopileInstallation        22.5    40.000000            NaN
# 64    MonopileInstallation        22.5    52.000000            NaN
# 78    MonopileInstallation        22.5    60.000000            NaN
# 91    MonopileInstallation        22.5    72.000000            NaN
# 104   MonopileInstallation        22.5    80.000000            NaN
# 120   MonopileInstallation        22.5    92.000000            NaN
# 128   MonopileInstallation        22.5   100.000000            NaN
# 141   MonopileInstallation        22.5   112.000000            NaN
# 151   MonopileInstallation        22.5   120.000000            NaN
# 161                    NaN         NaN   128.266667            NaN
# 162                    NaN         NaN   130.266667            NaN
# 164   MonopileInstallation        22.5   131.620833            NaN
# 166   MonopileInstallation        22.5   132.620833            NaN
# 171                    NaN         NaN   135.620833            NaN
# 172   MonopileInstallation        22.5   135.636806            NaN
# 173   MonopileInstallation        22.5   135.636808            NaN
# 174   MonopileInstallation        22.5   136.636808            NaN
# 177   MonopileInstallation        22.5   138.136808            NaN
# 180                    NaN         NaN   140.136808            NaN
# 181   MonopileInstallation        22.5   141.136808            NaN
# 182   MonopileInstallation        22.5   141.139122            NaN
# 184   MonopileInstallation        22.5   145.139122            NaN
# 187   MonopileInstallation        22.5   146.493289            NaN
# 190                    NaN         NaN   148.493289            NaN
# 191   MonopileInstallation        22.5   149.847456            NaN
# 193   MonopileInstallation        22.5   150.847456            NaN
# ...                    ...         ...          ...            ...
# 2289  MonopileInstallation        22.5  2041.144541            NaN
# 2293                   NaN         NaN  2049.411208            NaN
# 2294                   NaN         NaN  2051.411208            NaN
# 2297  MonopileInstallation        22.5  2052.765374            NaN
# 2298  MonopileInstallation        22.5  2053.765374            NaN
# 2299                   NaN         NaN  2056.765374            NaN
# 2300  MonopileInstallation        22.5  2066.765374            NaN
# 2301  MonopileInstallation        22.5  2066.781346            NaN
# 2302  MonopileInstallation        22.5  2066.781348            NaN
# 2303  MonopileInstallation        22.5  2067.781348            NaN
# 2305  MonopileInstallation        22.5  2069.781348            NaN
# 2306  MonopileInstallation        22.5  2071.281348            NaN
# 2307                   NaN         NaN  2073.281348            NaN
# 2308  MonopileInstallation        22.5  2074.281348            NaN
# 2309  MonopileInstallation        22.5  2074.283663            NaN
# 2312  MonopileInstallation        22.5  2078.283663            NaN
# 2315  MonopileInstallation        22.5  2079.637830            NaN
# 2316                   NaN         NaN  2081.637830            NaN
# 2317  MonopileInstallation        22.5  2082.991997            NaN
# 2318  MonopileInstallation        22.5  2083.991997            NaN
# 2321                   NaN         NaN  2086.991997            NaN
# 2322  MonopileInstallation        22.5  2087.007969            NaN
# 2323  MonopileInstallation        22.5  2087.007971            NaN
# 2326  MonopileInstallation        22.5  2088.007971            NaN
# 2327  MonopileInstallation        22.5  2089.507971            NaN
# 2329                   NaN         NaN  2091.507971            NaN
# 2332  MonopileInstallation        22.5  2092.507971            NaN
# 2333  MonopileInstallation        22.5  2092.510286            NaN
# 2337  MonopileInstallation        22.5  2096.510286            NaN
# 2338  MonopileInstallation        22.5  2097.864452            NaN
#
# [775 rows x 16 columns]

# %% [markdown]
# ### Array cable design and installation

# %%
# Trip data
# project._phases['ArrayCableInstallation'].install_vessel.__dict__
# project._phases.keys()
# project._phases['ArraySystemDesign'].__dict__

project._phases['ArraySystemDesign'].detailed_output
# Out:
# {'array_system': {'cables': {'XLPE_630mm_66kV': {'cable_sections': [(2.957580471,
#       2),
#      (1.6199999999999999, 46),
#      (2.0403069939000003, 2)],
#     'linear_density': 45}}},
#  'array_system_num_strings': 5,
#  'array_system_total_length': 84.5157749298,
#  'array_system_length_by_type': {'XLPE_630mm_66kV': 84.5157749298},
#  'array_system_total_cost': 34397920.3964286,
#  'array_system_cost_by_type': {'XLPE_630mm_66kV': 34397920.3964286}}

# %%
# Installation and capital costs 
ac_time = np.round(project._phases['ArrayCableInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
ac_install_cost = np.round(project._phases['ArrayCableInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ac_capital_cost = np.round(project._phases['ArraySystemDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)
total_length = np.round(project._phases['ArraySystemDesign'].detailed_output['array_system_length_by_type']['XLPE_630mm_66kV'], 1)

print('Array cable total length: ',total_length , 'km')
print('Array cable install time: ', ac_time, 'days')
print('Array cable install cost: ', ac_install_cost, 'M Euros')
print('Array cable capital cost: ', ac_capital_cost, 'M Euros')
print('Array cable total cost: ', ac_capital_cost + ac_install_cost, 'M Euros')
# Out:
# Array cable total length:  84.5 km
# Array cable install time:  69.6 days
# Array cable install cost:  13.5 M Euros
# Array cable capital cost:  31.6 M Euros
# Array cable total cost:  45.1 M Euros

# %% [markdown]
# ### Export cable

# %%
project._phases['ExportSystemDesign'].detailed_output
# Out:
# {'export_system': {'interconnection_distance': 3,
#   'cable': {'linear_density': 80,
#    'sections': [45.0225],
#    'number': 2,
#    'cable_power': 342.9460597040872}},
#  'export_system_total_mass': 7203.6,
#  'export_system_total_length': 90.045,
#  'export_system_total_cost': 53756865.0,
#  'export_system_cable_power': 342.9460597040872}

# %%
# Installation and capital costs 
ec_time = np.round(project._phases['ExportCableInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
ec_install_cost = np.round(project._phases['ExportCableInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ec_capital_cost = np.round(project._phases['ExportSystemDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ec_total_length = np.round(project._phases['ExportSystemDesign'].detailed_output['export_system_total_length'], 1)

print('Export cable total length: ',ec_total_length , 'km')
print('Export cable install time: ', ec_time, 'days')
print('Export cable install cost: ', ec_install_cost, 'M Euros')
print('Export cable capital cost: ', ec_capital_cost, 'M Euros')
print('Export cable total cost: ', ec_capital_cost + ec_install_cost, 'M Euros')
# Out:
# Export cable total length:  90.0 km
# Export cable install time:  15.7 days
# Export cable install cost:  20.5 M Euros
# Export cable capital cost:  49.5 M Euros
# Export cable total cost:  70.0 M Euros

# %% [markdown]
# ### Offshore substation

# %%
project._phases['OffshoreSubstationDesign'].detailed_output
# proj_df.loc[proj_df['phase']=='OffshoreSubstationInstallation']
# Out:
# {'num_substations': 2,
#  'substation_mpt_rating': 230.0,
#  'substation_topside_mass': 1170.5,
#  'substation_topside_cost': 21472250.0,
#  'substation_substructure_mass': 714.5703579927265,
#  'substation_substructure_cost': 3480583.305483635}

# %%
# Installation and capital costs 
oss_time = np.round(project._phases['OffshoreSubstationInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
oss_install_cost = np.round(project._phases['OffshoreSubstationInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
oss_capital_cost = np.round(project._phases['OffshoreSubstationDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)

print('Offshore substation install time: ', oss_time, 'days')
print('Offshore substation install cost: ', oss_install_cost, 'M Euros')
print('Offshore substation capital cost: ', oss_capital_cost, 'M Euros')
print('Offshore substation total cost: ', oss_capital_cost + oss_install_cost, 'M Euros')
# Out:
# Offshore substation install time:  5.5 days
# Offshore substation install cost:  3.2 M Euros
# Offshore substation capital cost:  73.9 M Euros
# Offshore substation total cost:  77.10000000000001 M Euros

# %% [markdown]
# ### Onshore construction

# %%
proj_df.loc[(proj_df['phase']=='ExportCableInstallation') & (proj_df['action'] == 'Onshore Construction')]
# Out:
#                  action                 agent  cable_lay_speed          cost  \
# 5  Onshore Construction  Onshore Construction              NaN  1.841086e+07
#
#    cost_multiplier  duration  hub_height   level  location  max_waveheight  \
# 5              NaN       0.0         NaN  ACTION  Landfall             NaN
#
#    max_windspeed                    phase phase_name  site_depth  time  \
# 5            NaN  ExportCableInstallation        NaN         NaN   0.0
#
#    transit_speed
# 5            NaN

# %%
print('Onshore construction cost:', 1.84e7 * 1e-6 * usd_to_euro)
# Out:
# Onshore construction cost: 16.928

# %% [markdown]
# ### Scour protection

# %%
project._phases['ScourProtectionDesign'].scour_protection_tonnes
# project._phases['ScourProtectionDesign'].equilibrium
# Out:
# 2466

# %%
# Installation and capital costs 
scour_time = np.round(project._phases['ScourProtectionInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
scour_install_cost = np.round(project._phases['ScourProtectionInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
scour_capital_cost = np.round(project._phases['ScourProtectionDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)

print('Scour protection install time: ', scour_time, 'days')
print('Scour protection install cost: ', scour_install_cost, 'M Euros')
print('Scour protection capital cost: ', scour_capital_cost, 'M Euros')
print('Scour protection total cost: ', scour_capital_cost + scour_install_cost, 'M Euros')
# Out:
# Scour protection install time:  69.0 days
# Scour protection install cost:  12.0 M Euros
# Scour protection capital cost:  4.5 M Euros
# Scour protection total cost:  16.5 M Euros

# %%
proj_df.loc[proj_df['phase']=='ScourProtectionInstallation']
# Out:
#                 action       agent  cable_lay_speed           cost  \
# 1             Mobilize  SPI Vessel              NaN  180000.000000
# 8     Load SP Material  SPI Vessel              NaN   20000.000000
# 34             Transit  SPI Vessel              NaN  103333.333333
# 44    Drop SP Material  SPI Vessel              NaN   50000.000000
# 45             Transit  SPI Vessel              NaN    1312.500000
# 52    Drop SP Material  SPI Vessel              NaN   50000.000000
# 85             Transit  SPI Vessel              NaN  103333.333333
# 88    Load SP Material  SPI Vessel              NaN   20000.000000
# 119            Transit  SPI Vessel              NaN  103333.333333
# 129   Drop SP Material  SPI Vessel              NaN   50000.000000
# 130            Transit  SPI Vessel              NaN    1312.500000
# 138   Drop SP Material  SPI Vessel              NaN   50000.000000
# 163            Transit  SPI Vessel              NaN  103333.333333
# 170   Load SP Material  SPI Vessel              NaN   20000.000000
# 204            Transit  SPI Vessel              NaN  103333.333333
# 220   Drop SP Material  SPI Vessel              NaN   50000.000000
# 221            Transit  SPI Vessel              NaN    1312.500000
# 240   Drop SP Material  SPI Vessel              NaN   50000.000000
# 276            Transit  SPI Vessel              NaN  103333.333333
# 281   Load SP Material  SPI Vessel              NaN   20000.000000
# 318            Transit  SPI Vessel              NaN  103333.333333
# 334   Drop SP Material  SPI Vessel              NaN   50000.000000
# 335            Transit  SPI Vessel              NaN    1312.500000
# 346   Drop SP Material  SPI Vessel              NaN   50000.000000
# 364            Transit  SPI Vessel              NaN  103333.333333
# 369   Load SP Material  SPI Vessel              NaN   20000.000000
# 386            Transit  SPI Vessel              NaN  103333.333333
# 393   Drop SP Material  SPI Vessel              NaN   50000.000000
# 394            Transit  SPI Vessel              NaN    1312.500000
# 403   Drop SP Material  SPI Vessel              NaN   50000.000000
# ...                ...         ...              ...            ...
# 1600  Load SP Material  SPI Vessel              NaN   20000.000000
# 1619           Transit  SPI Vessel              NaN  103333.333333
# 1627  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1628           Transit  SPI Vessel              NaN    1312.500000
# 1637  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1663           Transit  SPI Vessel              NaN  103333.333333
# 1669  Load SP Material  SPI Vessel              NaN   20000.000000
# 1698           Transit  SPI Vessel              NaN  103333.333333
# 1709  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1711           Transit  SPI Vessel              NaN    1312.500000
# 1727  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1754           Transit  SPI Vessel              NaN  103333.333333
# 1764  Load SP Material  SPI Vessel              NaN   20000.000000
# 1792           Transit  SPI Vessel              NaN  103333.333333
# 1804  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1805           Transit  SPI Vessel              NaN    1312.500000
# 1816  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1838           Transit  SPI Vessel              NaN  103333.333333
# 1842  Load SP Material  SPI Vessel              NaN   20000.000000
# 1857           Transit  SPI Vessel              NaN  103333.333333
# 1867  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1868           Transit  SPI Vessel              NaN    1312.500000
# 1878  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1896           Transit  SPI Vessel              NaN  103333.333333
# 1900  Load SP Material  SPI Vessel              NaN   20000.000000
# 1922           Transit  SPI Vessel              NaN  103333.333333
# 1930  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1932           Transit  SPI Vessel              NaN    1312.500000
# 1944  Drop SP Material  SPI Vessel              NaN   50000.000000
# 1971           Transit  SPI Vessel              NaN  103333.333333
#
#       cost_multiplier   duration  hub_height   level location  max_waveheight  \
# 1                 0.5  72.000000         NaN  ACTION      NaN             NaN
# 8                 NaN   4.000000         NaN  ACTION      NaN             NaN
# 34                NaN  20.666667         NaN  ACTION      NaN             NaN
# 44                NaN  10.000000         NaN  ACTION      NaN             NaN
# 45                NaN   0.262500         NaN  ACTION      NaN             NaN
# 52                NaN  10.000000         NaN  ACTION      NaN             NaN
# 85                NaN  20.666667         NaN  ACTION      NaN             NaN
# 88                NaN   4.000000         NaN  ACTION      NaN             NaN
# 119               NaN  20.666667         NaN  ACTION      NaN             NaN
# 129               NaN  10.000000         NaN  ACTION      NaN             NaN
# 130               NaN   0.262500         NaN  ACTION      NaN             NaN
# 138               NaN  10.000000         NaN  ACTION      NaN             NaN
# 163               NaN  20.666667         NaN  ACTION      NaN             NaN
# 170               NaN   4.000000         NaN  ACTION      NaN             NaN
# 204               NaN  20.666667         NaN  ACTION      NaN             NaN
# 220               NaN  10.000000         NaN  ACTION      NaN             NaN
# 221               NaN   0.262500         NaN  ACTION      NaN             NaN
# 240               NaN  10.000000         NaN  ACTION      NaN             NaN
# 276               NaN  20.666667         NaN  ACTION      NaN             NaN
# 281               NaN   4.000000         NaN  ACTION      NaN             NaN
# 318               NaN  20.666667         NaN  ACTION      NaN             NaN
# 334               NaN  10.000000         NaN  ACTION      NaN             NaN
# 335               NaN   0.262500         NaN  ACTION      NaN             NaN
# 346               NaN  10.000000         NaN  ACTION      NaN             NaN
# 364               NaN  20.666667         NaN  ACTION      NaN             NaN
# 369               NaN   4.000000         NaN  ACTION      NaN             NaN
# 386               NaN  20.666667         NaN  ACTION      NaN             NaN
# 393               NaN  10.000000         NaN  ACTION      NaN             NaN
# 394               NaN   0.262500         NaN  ACTION      NaN             NaN
# 403               NaN  10.000000         NaN  ACTION      NaN             NaN
# ...               ...        ...         ...     ...      ...             ...
# 1600              NaN   4.000000         NaN  ACTION      NaN             NaN
# 1619              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1627              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1628              NaN   0.262500         NaN  ACTION      NaN             NaN
# 1637              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1663              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1669              NaN   4.000000         NaN  ACTION      NaN             NaN
# 1698              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1709              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1711              NaN   0.262500         NaN  ACTION      NaN             NaN
# 1727              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1754              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1764              NaN   4.000000         NaN  ACTION      NaN             NaN
# 1792              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1804              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1805              NaN   0.262500         NaN  ACTION      NaN             NaN
# 1816              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1838              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1842              NaN   4.000000         NaN  ACTION      NaN             NaN
# 1857              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1867              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1868              NaN   0.262500         NaN  ACTION      NaN             NaN
# 1878              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1896              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1900              NaN   4.000000         NaN  ACTION      NaN             NaN
# 1922              NaN  20.666667         NaN  ACTION      NaN             NaN
# 1930              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1932              NaN   0.262500         NaN  ACTION      NaN             NaN
# 1944              NaN  10.000000         NaN  ACTION      NaN             NaN
# 1971              NaN  20.666667         NaN  ACTION      NaN             NaN
#
#       max_windspeed                        phase                   phase_name  \
# 1               NaN  ScourProtectionInstallation                          NaN
# 8               NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 34              NaN  ScourProtectionInstallation                          NaN
# 44              NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 45              NaN  ScourProtectionInstallation                          NaN
# 52              NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 85              NaN  ScourProtectionInstallation                          NaN
# 88              NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 119             NaN  ScourProtectionInstallation                          NaN
# 129             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 130             NaN  ScourProtectionInstallation                          NaN
# 138             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 163             NaN  ScourProtectionInstallation                          NaN
# 170             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 204             NaN  ScourProtectionInstallation                          NaN
# 220             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 221             NaN  ScourProtectionInstallation                          NaN
# 240             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 276             NaN  ScourProtectionInstallation                          NaN
# 281             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 318             NaN  ScourProtectionInstallation                          NaN
# 334             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 335             NaN  ScourProtectionInstallation                          NaN
# 346             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 364             NaN  ScourProtectionInstallation                          NaN
# 369             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 386             NaN  ScourProtectionInstallation                          NaN
# 393             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 394             NaN  ScourProtectionInstallation                          NaN
# 403             NaN  ScourProtectionInstallation  ScourProtectionInstallation
# ...             ...                          ...                          ...
# 1600            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1619            NaN  ScourProtectionInstallation                          NaN
# 1627            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1628            NaN  ScourProtectionInstallation                          NaN
# 1637            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1663            NaN  ScourProtectionInstallation                          NaN
# 1669            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1698            NaN  ScourProtectionInstallation                          NaN
# 1709            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1711            NaN  ScourProtectionInstallation                          NaN
# 1727            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1754            NaN  ScourProtectionInstallation                          NaN
# 1764            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1792            NaN  ScourProtectionInstallation                          NaN
# 1804            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1805            NaN  ScourProtectionInstallation                          NaN
# 1816            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1838            NaN  ScourProtectionInstallation                          NaN
# 1842            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1857            NaN  ScourProtectionInstallation                          NaN
# 1867            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1868            NaN  ScourProtectionInstallation                          NaN
# 1878            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1896            NaN  ScourProtectionInstallation                          NaN
# 1900            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1922            NaN  ScourProtectionInstallation                          NaN
# 1930            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1932            NaN  ScourProtectionInstallation                          NaN
# 1944            NaN  ScourProtectionInstallation  ScourProtectionInstallation
# 1971            NaN  ScourProtectionInstallation                          NaN
#
#       site_depth         time  transit_speed
# 1            NaN     0.000000            NaN
# 8            NaN     4.000000            NaN
# 34           NaN    24.666667            NaN
# 44           NaN    34.666667            NaN
# 45           NaN    34.929167            NaN
# 52           NaN    44.929167            NaN
# 85           NaN    65.595833            NaN
# 88           NaN    69.595833            NaN
# 119          NaN    90.262500            NaN
# 129          NaN   100.262500            NaN
# 130          NaN   100.525000            NaN
# 138          NaN   110.525000            NaN
# 163          NaN   131.191667            NaN
# 170          NaN   135.191667            NaN
# 204          NaN   155.858333            NaN
# 220          NaN   165.858333            NaN
# 221          NaN   166.120833            NaN
# 240          NaN   176.120833            NaN
# 276          NaN   196.787500            NaN
# 281          NaN   200.787500            NaN
# 318          NaN   221.454167            NaN
# 334          NaN   231.454167            NaN
# 335          NaN   231.716667            NaN
# 346          NaN   241.716667            NaN
# 364          NaN   262.383333            NaN
# 369          NaN   266.383333            NaN
# 386          NaN   287.050000            NaN
# 393          NaN   297.050000            NaN
# 394          NaN   297.312500            NaN
# 403          NaN   307.312500            NaN
# ...          ...          ...            ...
# 1600         NaN  1331.916667            NaN
# 1619         NaN  1352.583333            NaN
# 1627         NaN  1362.583333            NaN
# 1628         NaN  1362.845833            NaN
# 1637         NaN  1372.845833            NaN
# 1663         NaN  1393.512500            NaN
# 1669         NaN  1397.512500            NaN
# 1698         NaN  1418.179167            NaN
# 1709         NaN  1428.179167            NaN
# 1711         NaN  1428.441667            NaN
# 1727         NaN  1438.441667            NaN
# 1754         NaN  1459.108333            NaN
# 1764         NaN  1463.108333            NaN
# 1792         NaN  1483.775000            NaN
# 1804         NaN  1493.775000            NaN
# 1805         NaN  1494.037500            NaN
# 1816         NaN  1504.037500            NaN
# 1838         NaN  1524.704167            NaN
# 1842         NaN  1528.704167            NaN
# 1857         NaN  1549.370833            NaN
# 1867         NaN  1559.370833            NaN
# 1868         NaN  1559.633333            NaN
# 1878         NaN  1569.633333            NaN
# 1896         NaN  1590.300000            NaN
# 1900         NaN  1594.300000            NaN
# 1922         NaN  1614.966667            NaN
# 1930         NaN  1624.966667            NaN
# 1932         NaN  1625.229167            NaN
# 1944         NaN  1635.229167            NaN
# 1971         NaN  1655.895833            NaN
#
# [155 rows x 16 columns]
